# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd
import folium
import seaborn as sns
import os

# Get parent directory i.e. where the repo is cloned from there we can access the data folder
base_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))+'/'

df = pd.read_pickle(base_dir+'0_datasets/REC_database_optimized.pkl')

pd.set_option('display.max_rows', None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7190252 entries, 0 to 7190251
# Data columns (total 17 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Owner                        category
#  1   Accreditation_Code           string
#  2   Fuel_Source_Active           bool
#  3   Fuel_Source_Display_Name     category
#  4   Generation_Year              category
#  5   Status.1                     category
#  6   Start_Serial                 int32
#  7   End_Serial                   int32
#  8   State                        category
#  9   Owner_Name                   category
#  10  Range_ID                     int32
#  11  Public_Registered_Person_ID  int32
#  12  Created_By                   category
#  13  Creation_Date_simple         datetime64[ns]
#  14  number_of_certificates       int32
#  15  Dominent zone                category
#  16  system_size_kW               float32
# ...

# %%
# rename Status.1 to Status
df.rename(columns={'Status.1': 'Status'}, inplace=True)
df.rename(columns={'Fuel_Source_Display_Name': 'Fuel_Source_Name'}, inplace=True)
df.rename(columns={'Creation_Date_simple': 'Creation_Date'}, inplace=True)
df.rename(columns={'number_of_certificates': 'Certificates_Quantity'}, inplace=True)
df.rename(columns={'Dominent zone': 'Dominent_Zone'}, inplace=True)
df.rename(columns={'system_size_kW': 'System_Size'}, inplace=True)
df.head(5)
# Out:
#                                                Owner Accreditation_Code
# 0                       Ashley Noon T/A Green Wiring         PVD2393168  \
# 1                               Solargain PV Pty Ltd         PVD2393190
# 2  Home Comfort and Sustainability Services Pty L...         PVD2393171
# 3  Home Comfort and Sustainability Services Pty L...         PVD2393172
# 4                                  Michael patterson         PVD2393173
#
#    Fuel_Source_Active         Fuel_Source_Name Generation_Year
# 0                True  S.G.U. - solar (deemed)            2015  \
# 1                True  S.G.U. - solar (deemed)            2015
# 2                True  S.G.U. - solar (deemed)            2015
# 3                True  S.G.U. - solar (deemed)            2015
# 4                True  S.G.U. - solar (deemed)            2015
#
#                  Status  Start_Serial  End_Serial State
# 0            Registered             1         105    WA  \
# ...

# %%
df.to_pickle(base_dir+'0_datasets/REC_database_optimized_cleaned.pkl')
df.to_csv(base_dir+'0_datasets/REC_database_optimized_cleaned.csv')
